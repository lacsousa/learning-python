# %% [markdown]
# # Agente Explicador de Regras do Futebol com RAG (LangChain)
#
# ## Curso: LangChain — Criando Chatbots Inteligentes com RAG (Foundation)
#
# ### Objetivo
# Construir um agente conversacional simples utilizando **Retrieval-Augmented Generation (RAG)** para responder perguntas sobre **regras do futebol**, com base em **documentos oficiais**.
#
# ---
#
# ### Conceitos abordados
# - Definição do problema
# - Seleção da base de conhecimento
# - Preparação dos documentos
# - Embeddings e banco vetorial
# - Recuperação de contexto (Retriever)
# - Integração com LLM
# - Testes e validação das respostas

# %% [markdown]
# ## Dependências
#
# Execute no terminal antes de rodar o notebook:
#
# ```bash
# pip install langchain langchain-community langchain-openai chromadb pypdf
# ```

# %%
# !pip uninstall -y langchain langchain-core langchain-community langchain-openai
# !pip install langchain==0.1.20 langchain-community==0.0.38 langchain-openai==0.1.7
# !pip install pypdf
# !pip install chromadb
# Out:
# zsh:1: command not found: pip
# zsh:1: command not found: pip
# zsh:1: command not found: pip
# zsh:1: command not found: pip

# %%
# Caminho do PDF com regras oficiais do futebol
CAMINHO_PDF = "regras_futebol.pdf"  # ajuste o caminho se necessário
import os
if not os.path.isfile(CAMINHO_PDF):
    print(f"Arquivo {CAMINHO_PDF} não encontrado — pulando carregamento de PDF.")
    documents = []
else:
    try:
        loader = PyPDFLoader(CAMINHO_PDF)
        documents = loader.load()
    except Exception as e:
        print('Erro ao carregar PDF:', e)
        documents = []
len(documents)
# Out:
# Arquivo regras_futebol.pdf não encontrado — pulando carregamento de PDF.
# 0

# %% [markdown]
# ## 1️⃣ Definição do Problema
#
# LLMs possuem conhecimento estático e podem alucinar.
# O objetivo aqui é garantir **respostas confiáveis**, conectando o modelo
# a documentos oficiais sobre regras do futebol.

# %%
# Caminho do PDF com regras oficiais do futebol
CAMINHO_PDF = "regras_futebol.pdf"  # ajuste o caminho se necessário

# Carrega o PDF
loader = PyPDFLoader(CAMINHO_PDF)
documents = loader.load()

# Quantidade de páginas carregadas
len(documents)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 # Caminho do PDF com regras oficiais do futebol
#       2 CAMINHO_PDF = "regras_futebol.pdf"  # ajuste o caminho se necessário
#       3
#       4 # Carrega o PDF
# ----> 5 loader = PyPDFLoader(CAMINHO_PDF)
#       6 documents = loader.load()
#       7
#       8 # Quantidade de páginas carregadas
#
# NameError: name 'PyPDFLoader' is not defined

# %%
documents ## O que é ?
# Out:
# []

# %% [markdown]
# ## 2️⃣ Preparação dos Documentos
#
# Os documentos precisam ser divididos em pequenos blocos
# para facilitar a recuperação de contexto.

# %%
# Divide os documentos em chunks menores
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = text_splitter.split_documents(documents)

len(chunks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Divide os documentos em chunks menores
# ----> 2 text_splitter = RecursiveCharacterTextSplitter(
#       3     chunk_size=500,
#       4     chunk_overlap=100
#       5 )
#
# NameError: name 'RecursiveCharacterTextSplitter' is not defined

# %%
chunks ## mostrar 3 pedaços
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 chunks ## mostrar 3 pedaços
#
# NameError: name 'chunks' is not defined

# %% [markdown]
# ## 3️⃣ Embeddings e Banco Vetorial
#
# Cada bloco de texto será convertido em vetores semânticos
# e armazenado em um banco vetorial.

# %%
# Inicializa embeddings
embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small",
    openai_api_key=""
)

# Cria o banco vetorial
vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory="./chroma_regras_futebol"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Inicializa embeddings
# ----> 2 embeddings = OpenAIEmbeddings(
#       3     model="text-embedding-3-small",
#       4     openai_api_key=""
#       5 )
#
# NameError: name 'OpenAIEmbeddings' is not defined

# %% [markdown]
# ## 4️⃣ Recuperação de Contexto (Retriever)
#
# O retriever busca os trechos mais relevantes
# para cada pergunta do usuário.

# %%
# Cria o retriever
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 3}
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Cria o retriever
# ----> 2 retriever = vectorstore.as_retriever(
#       3     search_type="similarity",
#       4     search_kwargs={"k": 3}
#       5 )
#
# NameError: name 'vectorstore' is not defined

# %% [markdown]
# ## 5️⃣ Integração com o LLM (RAG)
#
# O contexto recuperado será injetado no prompt
# enviado ao modelo de linguagem.

# %%
# Inicializa o modelo de linguagem
llm = ChatOpenAI(
    model="gpt-4o-mini",
    openai_api_key=""
)

# Cria a cadeia RAG
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Inicializa o modelo de linguagem
# ----> 2 llm = ChatOpenAI(
#       3     model="gpt-4o-mini",
#       4     openai_api_key=""
#       5 )
#
# NameError: name 'ChatOpenAI' is not defined

# %% [markdown]
# ## 6️⃣ Testes e Validação
#
# Agora podemos testar perguntas reais
# e validar se as respostas estão baseadas nos documentos.

# %%
# Pergunta de teste
pergunta = "Um jogador pode usar a mão para marcar um gol?"

# Executa a pergunta no agente RAG
resposta = qa_chain(pergunta)

print("Pergunta:")
print(pergunta)

print("\nResposta do Agente:")
print(resposta["result"])

print("\nTrechos utilizados como contexto:\n")

for i, doc in enumerate(resposta["source_documents"], start=1):
    print(f"--- Trecho {i} ---")
    print(f"Fonte: {doc.metadata.get('source', 'Documento desconhecido')}")
    print(f"Página: {doc.metadata.get('page', 'N/A')}")
    print("Conteúdo:")
    print(doc.page_content)
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 # Pergunta de teste
#       2 pergunta = "Um jogador pode usar a mão para marcar um gol?"
#       3
#       4 # Executa a pergunta no agente RAG
# ----> 5 resposta = qa_chain(pergunta)
#       6
#       7 print("Pergunta:")
#       8 print(pergunta)
#
# NameError: name 'qa_chain' is not defined

# %%
# Pergunta de teste 2
pergunta = "O que caracteriza a posição de impedimento no futebol?"

# Executa a pergunta no agente RAG
resposta = qa_chain(pergunta)

print("Pergunta:")
print(pergunta)

print("\nResposta do Agente:")
print(resposta["result"])

print("\nTrechos utilizados como contexto:\n")

for i, doc in enumerate(resposta["source_documents"], start=1):
    print(f"--- Trecho {i} ---")
    print(f"Fonte: {doc.metadata.get('source', 'Documento desconhecido')}")
    print(f"Página: {doc.metadata.get('page', 'N/A')}")
    print("Conteúdo:")
    print(doc.page_content)
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       1 # Pergunta de teste 2
#       2 pergunta = "O que caracteriza a posição de impedimento no futebol?"
#       3
#       4 # Executa a pergunta no agente RAG
# ----> 5 resposta = qa_chain(pergunta)
#       6
#       7 print("Pergunta:")
#       8 print(pergunta)
#
# NameError: name 'qa_chain' is not defined

# %% [markdown]
# ## ✅ Conclusão
#
# Este notebook demonstrou, de forma prática:
# - Como o RAG melhora a confiabilidade das respostas
# - Como conectar LLMs a documentos oficiais
# - Como construir um agente conversacional simples com LangChain
